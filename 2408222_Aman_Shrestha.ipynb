# %% [markdown]
# Problem - 1: Getting Started with Data Exploration - Some Warm up
# Exercises:
# 1. Data Exploration and Understanding:

# %% [markdown]
# Dataset Overview:
# 1. Load the dataset and display the first 10 rows.
# 2. Identify the number of rows and columns in the dataset.
# 3. List all the columns and their data types.

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Concepts of Technology of AI/asigement/WHR-2024-5CS037.csv')
print(df.head(10))
print(df.count())
print(df.info())
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %% [markdown]
# Basic Statistics:
# 1. Calculate the mean, median, and standard deviation for the Score column.
# 2. Identify the country with the highest and lowest happiness scores.

# %%
print("mean: ",df['score'].mean())
print("standard deviation: ", df['score'].std())
print("median: ",df['score'].median())
print()
highest_happiness_country = df.loc[df['score'].idxmax()]
lowest_happiness_country = df.loc[df['score'].idxmin()]
print("Country with the highest happiness score:")
print(highest_happiness_country)
print()
print("Country with the lowest happiness score:")
lowest_happiness_country
# Out:
# mean:  5.52758041958042
# standard deviation:  1.1707165099442995
# median:  5.785
#
# Country with the highest happiness score:
# Country name                    Finland
# score                             7.741
# Log GDP per capita                1.844
# Social support                    1.572
# Healthy life expectancy           0.695
# Freedom to make life choices      0.859
# Generosity                        0.142
# Perceptions of corruption         0.546
# Dystopia + residual               2.082
# Happiness Category                 High
# Name: 0, dtype: object
#
# Country with the lowest happiness score:
# Country name                    Afghanistan
# score                                 1.721
# Log GDP per capita                    0.628
# Social support                          0.0
# Healthy life expectancy               0.242
# Freedom to make life choices            0.0
# Generosity                            0.091
# Perceptions of corruption             0.088
# ...

# %% [markdown]
# Missing Values:
# 1. Check if there are any missing values in the dataset. If so, display the total count for each column.

# %%
df.isnull().sum()
# Out:
# Country name                    0
# score                           0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64

# %% [markdown]
# Filtering and Sorting:
# 1. Filter the dataset to show only the countries with a Score greater than 7.5.
# 2. For the filtered dataset - Sort the dataset by GDP per Capita in descending order and display the
# top 10 rows.

# %%
filtered_dataset = df.loc[df['score']>7.5]
filtered_dataset = filtered_dataset.sort_values('Log GDP per capita',ascending=False)
filtered_dataset.head(10)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 0      Finland  7.741               1.844           1.572
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# 0                    0.695                         0.859       0.142
#
#    Perceptions of corruption  Dystopia + residual
# 1                      0.548                1.881
# 2                      0.182                2.050
# 0                      0.546                2.082

# %% [markdown]
# Adding New Columns:
# 1. Create a new column called Happiness Category that categorizes countries into three categories
# based on their Score:
#
# Low − (Score < 4)
#
# Medium − (4 ≤ Score ≤ 6)
#
# High − (Score > 6)

# %%
def categories_score(score):
  if score < 4:
    return 'Low'
  elif 4 <= score <= 6:
    return 'Medium'
  else:
    return 'High'
df['Happiness Category'] = df['score'].apply(categories_score)
df.head(10)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %% [markdown]
# 2. Data Visualizations:
#
# Bar Plot: Plot the top 10 happiest countries by Score using a bar chart.

# %%
import matplotlib.pyplot as plt
top_10_happiest_countries = df[['Country name','score']].head(10)
top_10_happiest_countries.plot(x='Country name', y = 'score',kind='bar', title='top 10 happiest countries',ylabel='Score')
plt.show()

# %% [markdown]
# Line Plot: Plot the top 10 unhappiest countries by Score using a Line chart.

# %%
top_10_unhappiest_countries = df[['Country name','score']].sort_values('score').head(10)
plt.plot(top_10_unhappiest_countries['Country name'], top_10_unhappiest_countries['score'], marker='o')
plt.xlabel('Country Name')
plt.ylabel('Happiness Score')
plt.title('Top 10 Unhappiest Countries by Score')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Plot a histogram for the Score column to show its distribution and also interpret.

# %%
df['score'].plot(kind='hist',bins=20,edgecolor='black',xlabel='Happiness Score',ylabel='number of countries',title='distribution of Happiness Score')
plt.show()

# %% [markdown]
# Scatter Plot: Plot a scatter plot between GDP per Capita and Score to visualize their relationship.

# %%
df[['Log GDP per capita','score']].plot(kind='scatter',title='Relationship between GDP per capita and Happiness Score',x='Log GDP per capita',y='score')
plt.show()

# %% [markdown]
# Problem - 2 - Some Advance Data Exploration Task:

# %% [markdown]
# Task - 1 - Setup Task - Preparing the South-Asia Dataset:
#
# Steps:
# 1. Define the countries in South Asia with a list for example:
#
# south asian countries = ["Afghanistan", "Bangladesh", "Bhutan", "India",
#
# "Maldives", "Nepal", "Pakistan", "Srilanka"]
#
# 2. Use the list from step - 1 to filtered the dataset {i.e. filtered out matching dataset from list.}
# 3. Save the filtered dataframe as separate CSV files for future use.

# %%
south_asian_countries = ['Afghanistan','Bangladesh', 'Bhutan', 'India', 'Maldives', 'Nepal', 'Pakistan', 'Sri Lanka']
df_south_asian = df[df['Country name'].isin(south_asian_countries)]
df_south_asian.to_csv('south_asia_happiness_index.csv')

# %% [markdown]
# Task - 2 - Composite Score Ranking:
#
# Tasks:
# 1. Using the SouthAsia DataFrame, create a new column called Composite Score that combines the
# following metrics:
#
# Composite Score = 0.40 × GDP per Capita + 0.30 × Social Support + 0.30 × Healthy Life Expectancy
# 2. Rank the South Asian countries based on the Composite Score in descending order.
# 3. Visualize the top 5 countries using a horizontal bar chart showing the Composite Score.
# 4. Discuss whether the rankings based on the Composite Score align with the original Score - support your discussion with some visualization plot.

# %%
original_top_5_countries = df_south_asian.head(5)
original_top_5_countries[['Country name','score']].plot(kind='barh',x='Country name',y='score',xlabel='Score',ylabel='Country',title='top 5 south asian countries by score')
plt.show()
df_south_asian['Composite Score'] = 0.40 * df_south_asian['Log GDP per capita'] + 0.30 * df_south_asian['Social support'] + 0.30 * df_south_asian['Healthy life expectancy']
sorted_df_south_asian = df_south_asian.sort_values('Composite Score', ascending=False)
top_5_countries = sorted_df_south_asian.head(5)
top_5_countries[['Country name','Composite Score']].plot(kind='barh',x='Country name',y='Composite Score',xlabel='Composite Score',ylabel = 'Country',title='Top 5 south asian countries by Composite Score')
plt.show()
# Out:
# <ipython-input-19-f73452cb21cb>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_south_asian['Composite Score'] = 0.40 * df_south_asian['Log GDP per capita'] + 0.30 * df_south_asian['Social support'] + 0.30 * df_south_asian['Healthy life expectancy']

# %% [markdown]
# Task - 3 - Outlier Detection:
#
# Tasks:
# 1. Identify outlier countries in South Asia based on their Score and GDP per Capita.
# 2. Define outliers using the 1.5 × IQR rule.
# 3. Create a scatter plot with GDP per Capita on the x-axis and Score on the y-axis, highlighting outliers
# in a different color.
# 4. Discuss the characteristics of these outliers and their potential impact on regional averages.

# %%
def find_outliers_iqr(data):
  q1 = data.quantile(0.25)
  q3 = data.quantile(0.75)
  iqr = q3 - q1
  outliers = data[(data < (q1 - 1.5 * iqr)) | (data > (q3 + 1.5 * iqr))]
  return outliers

outliers = find_outliers_iqr(df_south_asian[['score','Log GDP per capita']])
outliers = outliers.dropna()
print("Outliers: ")
outliers_index = outliers.index
print(df_south_asian[['Country name', 'score', 'Log GDP per capita']].loc[outliers_index[0]])

plt.scatter(df_south_asian['Log GDP per capita'], df_south_asian['score'], label='Countries')
plt.scatter(outliers['Log GDP per capita'], outliers['score'], color='red', label='Outliers')
plt.xlabel('Log GDP per Capita')
plt.ylabel('Score')
plt.title('Outliers in South Asian Countries')
plt.legend()
plt.show()
# Out:
# Outliers:
# Country name          Afghanistan
# score                       1.721
# Log GDP per capita          0.628
# Name: 142, dtype: object

# %% [markdown]
# Task - 4 - Exploring Trends Across Metrics:
#
# Tasks:
# 1. Choose two metrics (e.g., Freedom to Make Life Choices and Generosity) and calculate their correlation
# {pearson correlation} with the Score for South Asian countries.
# 2. Create scatter plots with trendlines for these metrics against the Score.
# 3. Identify and discuss the strongest and weakest relationships between these metrics and the Score for
# South Asian countries.

# %%
import seaborn as sns
correlation_freedom = df_south_asian['Freedom to make life choices'].corr(df_south_asian['score'])
correlation_generosity = df_south_asian['Generosity'].corr(df_south_asian['score'])
print(f"Correlation between Freedom to make life choices and Score: {correlation_freedom}")
print(f"Correlation between Generosity and Score: {correlation_generosity}")
sns.regplot(x='Generosity', y='score', data=df_south_asian)
sns.regplot(x='Freedom to make life choices', y='score', data=df_south_asian)
plt.scatter(df_south_asian['Freedom to make life choices'],df_south_asian['score'],label='Freedom to make life choices')
plt.scatter(df_south_asian['Generosity'],df_south_asian['score'],color='green',label='Generosity')
plt.legend()
plt.xlabel('Freedom to make life choices / Generosity')
plt.show()
# Out:
# Correlation between Freedom to make life choices and Score: 0.8005185224163315
# Correlation between Generosity and Score: 0.874512371253192

# %% [markdown]
# Task - 5 - Gap Analysis:
#
# Tasks:
# 1. Add a new column, GDP-Score Gap, which is the difference between GDP per Capita and the Score
# for each South Asian country.
# 2. Rank the South Asian countries by this gap in both ascending and descending order.
# 3. Highlight the top 3 countries with the largest positive and negative gaps using a bar chart.
# 4. Analyze the reasons behind these gaps and their implications for South Asian countries.

# %%
df_south_asian['GDP_Score_Gap'] = df_south_asian['Log GDP per capita'] - df_south_asian['score']
df_south_asian_ascending_order = df_south_asian.sort_values('GDP_Score_Gap')
df_south_asian_descending_order = df_south_asian.sort_values('GDP_Score_Gap',ascending=False)
top_3_negative_gap = df_south_asian_ascending_order.head(3)
top_3_positive_gap = df_south_asian_descending_order.head(3)
plt.bar(top_3_positive_gap['Country name'],top_3_positive_gap['GDP_Score_Gap'],label = 'positive gap')
plt.bar(top_3_negative_gap['Country name'],top_3_negative_gap['GDP_Score_Gap'],color='red',label = 'negative gap')
plt.xlabel('Country name')
plt.ylabel('GDP Score Gap')
plt.title('Top 3 Positive and Negative GDP-Score Gaps in South Asia')
plt.legend()
plt.show()
# Out:
# <ipython-input-22-0a82feb8ada6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_south_asian['GDP_Score_Gap'] = df_south_asian['Log GDP per capita'] - df_south_asian['score']

# %% [markdown]
# 3.3 Problem - 3 - Comparative Analysis:
#
# Task - 1 - Setup Task - Preparing the Middle Eastern Dataset:
#
# Tasks:
# 1. Similar in Task - 1 of Problem 2 create a dataframe from middle eastern countries. For hint use the
# following list:
#
# middle east countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
# "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria",
# "United Arab Emirates", "Yemen"]
#
# Complete the following task:

# %%
middle_east_countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan", "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria", "United Arab Emirates", "Yemen"]
df_middle_east_countries = df[df['Country name'].isin(middle_east_countries)]
df_middle_east_countries
# Out:
#              Country name  score  Log GDP per capita  Social support  \
# 4                  Israel  7.341               1.803           1.513
# 12                 Kuwait  6.951               1.845           1.364
# 21   United Arab Emirates  6.733               1.983           1.164
# 27           Saudi Arabia  6.594               1.842           1.361
# 61                Bahrain  5.959                 NaN             NaN
# 91                   Iraq  5.166               1.249           0.996
# 99                   Iran  4.923               1.435           1.136
# 124                Jordan  4.186               1.262           0.983
# 132                 Yemen  3.561               0.671           1.281
# 141               Lebanon  2.707               1.377           0.577
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                      0.740                         0.641       0.153
# ...

# %% [markdown]
# 1. Descriptive Statistics:
#
# • Calculate the mean, Standard deviation of the score for both South Asia and Middle East.
#
# • Which region has higher happiness Scores on average?

# %%
print(f"South Asian mean on Happiness Score  = {df_south_asian['score'].mean()}")
print(f"South Asian standard deviation on Happiness Score  = {df_south_asian['score'].std()}")
print()
print(f"Middle East mean on Happiness Score = {df_middle_east_countries['score'].mean()}")
print(f"Middle East standart deviation on Happiness Score = {df_middle_east_countries['score'].std()}")

# middle east region has the higher happiness scores on average
# Out:
# South Asian mean on Happiness Score  = 3.895666666666667
# South Asian standard deviation on Happiness Score  = 1.1770690152521504
#
# Middle East mean on Happiness Score = 5.412100000000001
# Middle East standart deviation on Happiness Score = 1.5662011684327144

# %% [markdown]
# 2. Top and Bottom Performers:
#
# • Identify the top 3 and bottom 3 countries in each region based on the score.
#
# • Plot bar charts comparing these charts.

# %%
sorted_df_south_asian = df_south_asian[['Country name','score']].sort_values('score',ascending=False)
sorted_df_middle_east = df_middle_east_countries[['Country name','score']].sort_values('score',ascending=False)
top_3_south_asian_countries = sorted_df_south_asian.head(3)
bottom_3_south_asian_countries = sorted_df_south_asian.tail(3)
top_3_middle_east_countries = sorted_df_middle_east.head(3)
bottom_3_middle_east_countries = sorted_df_middle_east.tail(3)
top_3_south_asian_countries.plot(kind='bar',x='Country name',y='score',title='top 3 south asian countries')
top_3_middle_east_countries.plot(kind='bar',x='Country name',y='score',title='top 3 middle east countries')
bottom_3_south_asian_countries.plot(kind='bar',x='Country name',y='score',title='bottom 3 south asian countries')
bottom_3_middle_east_countries.plot(kind='bar',x='Country name',y='score',title='bottom 3 middle east countries')
# Out:
# <Axes: title={'center': 'bottom 3 middle east countries'}, xlabel='Country name'>

# %% [markdown]
# 3. Metric Comparisons:
#
# • Compare key metrics like GDP per Capita, Social Support, and Healthy Life Expectancy between the regions using grouped bar charts.
#
# • Which metrics show the largest disparity between the two regions?

# %%
south_asian_key_matrics = df_south_asian[['Log GDP per capita','Social support', 'Healthy life expectancy']].mean()
middle_east_key_matrics = df_middle_east_countries[['Log GDP per capita','Social support', 'Healthy life expectancy']].mean()
data = {
    'Region': ['South Asia', 'Middle East'],
    'GDP per Capita': [south_asian_key_matrics['Log GDP per capita'], middle_east_key_matrics['Log GDP per capita']],
    'Social Support': [south_asian_key_matrics['Social support'], middle_east_key_matrics['Social support']],
    'Healthy Life Expectancy': [south_asian_key_matrics['Healthy life expectancy'], middle_east_key_matrics['Healthy life expectancy']]
}
metrics_comparison = pd.DataFrame(data)
metrics_comparison.plot(kind='bar',x='Region',title='Comparison of Key Metrics between South Asia and Middle East',ylabel='Average score',xlabel='Metrics')
plt.show()
matrics_disparity = abs(south_asian_key_matrics - middle_east_key_matrics)
largest_disparity = matrics_disparity.sort_values(ascending=False).head(1)
print(f"largest disparity between the two regions: {largest_disparity}")
# Out:
# Log GDP per capita         0.444500
# Social support             0.540944
# Healthy life expectancy    0.133778
# dtype: float64
# largest disparity between the two regions: Social support    0.540944
# dtype: float64

# %% [markdown]
# 4. Happiness Disparity:
#
# • Compute the range (max - min) and coefficient of variation (CV) for Score in both regions.
#
# • Which region has greater variability in happiness?

# %%
south_asia_range = df_south_asian['score'].max() - df_south_asian['score'].min()
south_asia_cv = df_south_asian['score'].std() / df_south_asian['score'].mean() * 100
print(f"the range of south asia: {south_asia_range}")
print(f"the cv of south asia: {south_asia_cv}")
middle_east_range = df_middle_east_countries['score'].max() - df_middle_east_countries['score'].min()
middle_east_cv = df_middle_east_countries['score'].std() / df_middle_east_countries['score'].mean() * 100
print(f"the range of middle east: {middle_east_range}")
print(f"the cv of middle east: {middle_east_cv}")

# South Asia has greater variability in happiness compare to Middle East.
# Out:
# the range of south asia: 3.4370000000000003
# the cv of south asia: 30.21482883337427
# the range of middle east: 4.634
# the cv of middle east: 28.938880812119404

# %% [markdown]
# 5. Correlation Analysis:
#
# • Analyze the correlation of Score with other metrics Freedom to Make Life Choices, and Generosity within each region.
#
# • Create scatter plots to visualize and interpret the relationships.

# %%
south_asia_correlation_freedom = df_south_asian['score'].corr(df_south_asian['Freedom to make life choices'])
south_asia_correlation_generosity = df_south_asian['score'].corr(df_south_asian['Generosity'])
print(f"the correlation of Score with Freedom to Make Life Choices within south asia: {south_asia_correlation_freedom}")
print(f"the correlation of Score with Generosity within south asia: {south_asia_correlation_generosity}")
print()
middle_east_correlation_freedom = df_middle_east_countries['score'].corr(df_middle_east_countries['Freedom to make life choices'])
middle_east_correlation_generosity = df_middle_east_countries['score'].corr(df_middle_east_countries['Generosity'])
print(f"the correlation of Score with Freedom to Make Life Choices within middle east: {middle_east_correlation_freedom}")
print(f"the correlation of Score with Generosity within middle east: {middle_east_correlation_generosity}")

plt.scatter(df_south_asian['Freedom to make life choices'],df_south_asian['score'],label='Freedom')
plt.scatter(df_south_asian['Generosity'],df_south_asian['score'],label='Generosity',color='green')
plt.xlabel('Freedom to make life choices / Generosity')
plt.ylabel('score')
plt.title('South Asia')
plt.legend()
plt.show()

plt.scatter(df_middle_east_countries['Freedom to make life choices'],df_middle_east_countries['score'],label='Freedom')
plt.scatter(df_middle_east_countries['Generosity'],df_middle_east_countries['score'],label='Generosity',color='green')
plt.xlabel('Freedom to make life choices / Generosity')
plt.ylabel('score')
plt.title('Middle East')
plt.legend()
plt.show()
# Out:
# the correlation of Score with Freedom to Make Life Choices within south asia: 0.8005185224163315
# the correlation of Score with Generosity within south asia: 0.874512371253192
#
# the correlation of Score with Freedom to Make Life Choices within middle east: 0.8632202433827544
# the correlation of Score with Generosity within middle east: 0.6275236536964182

# %% [markdown]
# 6. Outlier Detection:
#
# • Identify outlier countries in both regions based on Score and GDP per Capita.
#
# • Plot these outliers and discuss their implications.

# %%
south_asia_outliers = find_outliers_iqr(df_south_asian[['score','Log GDP per capita']])
south_asia_outliers = south_asia_outliers.dropna()
middle_east_outliers = find_outliers_iqr(df_middle_east_countries[['score','Log GDP per capita']])
middle_east_outliers = middle_east_outliers.dropna()
plt.scatter(df_south_asian['Log GDP per capita'],df_south_asian['score'],label='Countries')
plt.scatter(south_asia_outliers['Log GDP per capita'],south_asia_outliers['score'],color='red',label='Outlier')
plt.title('Outliers in South Asian Countries')
plt.xlabel('Log GDP per Capita')
plt.ylabel('Score')
plt.legend()
plt.show()

plt.scatter(df_middle_east_countries['Log GDP per capita'],df_middle_east_countries['score'],label='Countries')
plt.scatter(middle_east_outliers['Log GDP per capita'],middle_east_outliers['score'],color='red',label='Outlier')
plt.title('Outliers in Middle East Countries')
plt.xlabel('Log GDP per Capita')
plt.ylabel('Score')
plt.legend()
plt.show()

# %% [markdown]
# 7. Visualization:
#
# • Create boxplots comparing the distribution of Score between South Asia and the Middle East.
#
# • Interpret the key differences in distribution shapes, medians, and outliers.

# %%
df_south_asian['score'].plot(kind='box',title='Boxplot of South Asia')
plt.show()
df_middle_east_countries['score'].plot(kind='box',title='Boxplot of Middle East')
plt.show()
